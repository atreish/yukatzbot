# %%
import openai
import os

from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv())

openai.api_key  = os.getenv('OPENAI_API_KEY')

# %%
def get_completion(prompt, model="gpt-3.5-turbo"):
    messages = [{"role": "user", "content": prompt}]
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=0, # this is the degree of randomness of the model's output
    )
    return response.choices[0].message["content"]

# %%
admission_text = f"""
What are the admission requirements and how do I apply?
Please submit the following required document in order to apply:
Transcripts from all colleges/universities attended
Degree Conferral (Diploma or certificate)
English language assessment (Duolingo: 110, TOEFL: 85 (not accepting home edition), IELTS: 6.5, and PTE: 59.)
Resume
Statement of Purpose
GRE/GMAT scores (Physics+ Math only)
Letters of recommendation (Physics+ Math only)  
Admission page: https://www.yu.edu/katz/admissions/grad-admissions
https://www.yu.edu/sites/default/files/inline-files/FINAL%20Application%20Checklist%20for%20Graduate%20STEM%20Programs%20-%20010423_0.pdf 
What are the program's curriculum and research opportunities? Please send student program curriculum via website. (Can be found under Helpful Links under program page)
https://www.yu.edu/katz/research
https://www.yu.edu/katz/research-symposium-2023
https://www.yu.edu/katz/research-symposium-2022
What is the cost of the program, and are there any scholarships or financial aid options available? The STEM Fellows Scholarship is awarded to qualified and admitted students which reduces your tuition to $25,000 plus semesterly fees which is part of the STEM Fellows Scholarship. The additional semesterly fees that you would be responsible for can all be viewed online
https://www.yu.edu/katz/stem-fellows
What is the application deadline, and when can I expect to hear back from the admission team? For the Fall 2023 semester, our priority deadline is June 1st however, we encourage you to complete your application sooner, so it allows enough time for visa processing.
Admission page: https://www.yu.edu/katz/admissions/grad-admissions
https://www.yu.edu/sites/default/files/inline-files/FINAL%20Application%20Checklist%20for%20Graduate%20STEM%20Programs%20-%20010423_0.pdf

What is the acceptance rate for the program, and how competitive is it? Some of our STEM programs do have pre-requisites that students are required to have completed prior to the program (DAV and AI). Typically, we ask students to have a minimum of a 3.0 GPA however, we do still encourage you to apply. If we need any additional documents to review your application, we would be sure to be in touch. 
What are the program's rankings and reputation?  https://www.yu.edu/sites/default/files/inline-files/Katz%20Viewbook%20-%202023_0.pdf 
What are the opportunities for internships, co-op programs, and job placement after graduation? Our graduates have a 95% employment rate within 6 months of graduation. Students can begin to apply for internships once they are legally eligible to in the U.S. however, the program does not assist with placements. If you do find an internship, then you can pursue the internship course as part of your program and earn credit.
What is the student-faculty ratio and how accessible are professors to students? We prefer to keep our class sizes small so students can have a more personal experience with our faculty and other students on their program. 
What is the campus life like, and what extracurricular activities are available? Please see our student life page below:  https://www.yu.edu/katz/students
Do I have to pay a deposit to secure my spot? Students are required to submit the $500 non-refundable deposit. For international students, once we receive your deposit our Office of International Services will then be in touch about accessing your I-20 application and the international portal. 
How long does the program take? Depending on the program, it can take students 1.5-2 years (15-21 months). Please confirm on program page on the website."""

prompt = f"""
From the provided list of questions and answers in the admission_text, do below activities that are required to build /
a chatbot for the university using RASA framework to address student questions:

step1: Generate different types of questions and answers which are required as examples for RASA
step2: Extract entities from each of the generated  questions
step3: Group/cluster each of the extracted entity into one of the parent entities. I need just 10 parent entities
step4: Display the output of each entitity and its respective parent entity

\"\"\"{admission_text}\"\"\"
"""
response = get_completion(prompt)
print("Completion for text:")
print(response)
# Out:
# Completion for text:
# Step 1: Generate different types of questions and answers which are required as examples for RASA
#
# 1. Q: What are the admission requirements and how do I apply?
#    A: Please submit the following required documents in order to apply:
#       - Transcripts from all colleges/universities attended
#       - Degree Conferral (Diploma or certificate)
#       - English language assessment (Duolingo: 110, TOEFL: 85 (not accepting home edition), IELTS: 6.5, and PTE: 59.)
#       - Resume
#       - Statement of Purpose
#       - GRE/GMAT scores (Physics+ Math only)
#       - Letters of recommendation (Physics+ Math only)
#       - For more information, please visit our admission page: [Admission Page](https://www.yu.edu/katz/admissions/grad-admissions)
#
# 2. Q: What are the program's curriculum and research opportunities?
#    A: Please send the student program curriculum via our website. It can be found under Helpful Links on the program page.
#       - For more information, please visit our research page: [Research Page](https://www.yu.edu/katz/research)
#
# 3. Q: What is the cost of the program, and are there any scholarships or financial aid options available?
#    A: The STEM Fellows Scholarship is awarded to qualified and admitted students, which reduces your tuition to $25,000 plus semesterly fees. The additional semesterly fees can be viewed online.
#       - For more information, please visit our STEM Fellows Scholarship page: [STEM Fellows Scholarship](https://www.yu.edu/katz/stem-fellows)
#
# 4. Q: What is the application deadline, and when can I expect to hear back from the admission team?
#    A: For the Fall 2023 semester, our priority deadline is June 1st. However, we encourage you to complete your application sooner to allow enough time for visa processing.
#       - For more information, please visit our admission page: [Admission Page](https://www.yu.edu/katz/admissions/grad-admissions)
#
# 5. Q: What is the acceptance rate for the program, and how competitive is it?
#    A: Some of our STEM programs have prerequisites that students are required to have completed prior to the program. Typically, we ask students to have a minimum GPA of 3.0. However, we still encourage you to apply. If we need any additional documents to review your application, we will be in touch.
#
# 6. Q: What are the program's rankings and reputation?
#    A: Please refer to our viewbook for information on the program's rankings and reputation: [Viewbook](https://www.yu.edu/sites/default/files/inline-files/Katz%20Viewbook%20-%202023_0.pdf)
#
# 7. Q: What are the opportunities for internships, co-op programs, and job placement after graduation?
#    A: Our graduates have a 95% employment rate within 6 months of graduation. Students can begin to apply for internships once they are legally eligible to work in the U.S. However, the program does not assist with placements. If you find an internship, you can pursue the internship course as part of your program and earn credit.
#
# 8. Q: What is the student-faculty ratio and how accessible are professors to students?
#    A: We prefer to keep our class sizes small so students can have a more personal experience with our faculty and other students in their program.
#
# 9. Q: What is the campus life like, and what extracurricular activities are available?
#    A: Please visit our student life page for information on campus life and available extracurricular activities: [Student Life Page](https://www.yu.edu/katz/students)
#
# 10. Q: Do I have to pay a deposit to secure my spot?
#     A: Students are required to submit a $500 non-refundable deposit. For international students, once we receive your deposit, our Office of International Services will be in touch about accessing your I-20 application and the international portal.
#
# 11. Q: How long does the program take?
#     A: Depending on the program, it can take students 1.5-2 years (15-21 months). Please confirm the duration on the program page on our website.
#
# Step 2: Extract entities from each of the generated questions
#
# 1. Admission requirements, apply, transcripts, colleges/universities, degree conferral, diploma, certificate, English language assessment, Duolingo, TOEFL, IELTS, PTE, resume, statement of purpose, GRE, GMAT, physics, math, letters of recommendation, admission page.
#
# 2. Program's curriculum, research opportunities, student program curriculum, website, helpful links, program page, research page.
#
# 3. Cost of the program, scholarships, financial aid options, STEM Fellows Scholarship, tuition, semesterly fees, STEM Fellows Scholarship page.
#
# 4. Application deadline, hear back, admission team, Fall 2023 semester, priority deadline, June 1st, visa processing, admission page.
#
# 5. Acceptance rate, competitive, STEM programs, prerequisites, GPA, additional documents.
#
# 6. Program's rankings, reputation, viewbook.
#
# 7. Internships, co-op programs, job placement, graduates, employment rate, internships, U.S., internship course, credit.
#
# 8. Student-faculty ratio, professors, class sizes, personal experience.
#
# 9. Campus life, extracurricular activities, student life page.
#
# 10. Deposit, secure spot, $500 non-refundable deposit, international students, Office of International Services, I-20 application, international portal.
#
# 11. Program duration, program page, website.
#
# Step 3: Group/cluster each of the extracted entities into one of the parent entities. I need just 10 parent entities
#
# 1. Admission Requirements: transcripts, colleges/universities, degree conferral, English language assessment, resume, statement of purpose, GRE/GMAT scores, letters of recommendation, admission page.
#
# 2. Program Information: curriculum, research opportunities, program curriculum, website, helpful links, program page, research page.
#
# 3. Cost and Financial Aid: cost of the program, scholarships, financial aid options, STEM Fellows Scholarship, tuition, semesterly fees, STEM Fellows Scholarship page.
#
# 4. Application Process: application deadline, hear back, admission team, Fall 2023 semester, priority deadline, visa processing, admission page.
#
# 5. Program Competitiveness: acceptance rate, competitive, STEM programs, prerequisites, GPA, additional documents.
#
# 6. Rankings and Reputation: program's rankings, reputation, viewbook.
#
# 7. Internships and Job Placement: internships, co-op programs, job placement, graduates, employment rate, internships, internship course, credit.
#
# 8. Student-Faculty Interaction: student-faculty ratio, professors, class sizes, personal experience.
#
# 9. Campus Life and Activities: campus life, extracurricular activities, student life page.
#
# 10. Deposit and Enrollment: deposit, secure spot, $500 non-refundable deposit, international students, Office of International Services, I-20 application, international portal.
#
# Step 4: Display the output of each entity and its respective parent entity
#
# 1. Admission Requirements:
#    - Transcripts from all colleges/universities attended
#    - Degree Conferral (Diploma or certificate)
#    - English language assessment (Duolingo: 110, TOEFL: 85 (not accepting home edition), IELTS: 6.5, and PTE: 59.)
#    - Resume
#    - Statement of Purpose
#    - GRE/GMAT scores (Physics+ Math only)
#    - Letters of recommendation (Physics+ Math only)
#    - Admission page
#
# 2. Program Information:
#    - Curriculum
#    - Research opportunities
#    - Student program curriculum
#    - Website
#    - Helpful links
#    - Program page
#    - Research page
#
# 3. Cost and Financial Aid:
#    - Cost of the program
#    - Scholarships
#    - Financial aid options
#    - STEM Fellows Scholarship
#    - Tuition
#    - Semesterly fees
#    - STEM Fellows Scholarship page
#
# 4. Application Process:
#    - Application deadline
#    - Hear back
#    - Admission team
#    - Fall 2023 semester
#    - Priority deadline
#    - Visa processing
#    - Admission page
#
# 5. Program Competitiveness:
#    - Acceptance rate
#    - Competitive
#    - STEM programs
#    - Prerequisites
#    - GPA
#    - Additional documents
#
# 6. Rankings and Reputation:
#    - Program's rankings
#    - Reputation
#    - Viewbook
#
# 7. Internships and Job Placement:
#    - Internships
#    - Co-op programs
#    - Job placement
#    - Graduates
#    - Employment rate
#    - Internship course
#    - Credit
#
# 8. Student-Faculty Interaction:
#    - Student-faculty ratio
#    - Professors
#    - Class sizes
#    - Personal experience
#
# 9. Campus Life and Activities:
#    - Campus life
#    - Extracurricular activities
#    - Student life page
#
# 10. Deposit and Enrollment:
#     - Deposit
#     - Secure spot
#     - $500 non-refundable deposit
#     - International students
#     - Office of International Services
#     - I-20 application
#     - International portal
