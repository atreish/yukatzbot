# %% [markdown]
# # DOWNLOAD FILE ENTITIES

# %%
import requests

# %%
file_name='entities.txt'

# %%
file_entities=open(file_name)

# %%
entities=file_entities.readlines()

# %%
len(entities)
# Out:
# 1326

# %% [markdown]
# # DATA CLEANING

# %%
import re

# %%
primarary_entities=re.findall(r'Primary (?:entity|entities): [A-Za-z\s\.-]+',' '.join(entities))

# %%
len(primarary_entities)
# Out:
# 1295

# %%
primarary_entities
# Out:
# ['Primary entity: Steinberg Library',
#  'Primary entities: Counseling Center',
#  'Primary entity: Wilf Campus libraries',
#  'Primary entity: Mendel Gottesman ',
#  'Primary entity: Resnick Campus library',
#  'Primary entity: website',
#  'Primary entity: Samuel Gottesman Library',
#  'Primary entity: Office of Disability Services',
#  'Primary entity: Counseling Center',
#  'Primary entity: Counseling Center',
#  'Primary entity: registration',
#  'Primary entity: students',
#  'Primary entities: students',
#  'Primary entity: CRN',
#  'Primary entities: time',
#  'Primary entities: students',
#  'Primary entity: Katz School',
#  'Primary entity: students',
#  'Primary entities: social media platforms',
#  'Primary entity: Abraham Oxilas',
#  'Primary entity: Abraham Oxilas',
#  'Primary entity: Abraham Oxilas',
#  'Primary entity: Abraham Oxilas',
#  'Primary entity: Abraham Oxilas',
#  'Primary entity: Abraham Oxilas',
#  'Primary entity: Abraham Oxilas',
# ...

# %%
regex_delete_number=r'\d+.'
regex_del_title=r'Dr.'
regex_del_quotion_mark_start=r"^('|\[')"
regex_del_quotion_mark_end=r"',$"
regex_del_quotion_period=r'\.$'
regex_del_quotion_dash=r'^(-|")'

# %%
for i,entity in enumerate(primarary_entities):
  entity=re.sub(regex_delete_number,'',entity)
  entity=re.sub(regex_del_title,'',entity)
  entity=re.sub(regex_del_quotion_mark_start,'',entity)
  entity=re.sub(regex_del_quotion_mark_end,'',entity)

  entity=re.sub(regex_del_quotion_period,'',entity)
  entity=re.sub(regex_del_quotion_period,'',entity)

  entity=re.sub(regex_del_quotion_period,'',entity)
  entity=re.sub(regex_del_quotion_dash,'',entity)
  entity=re.sub(r'primary (?:entity|entities): ','',entity)


  primarary_entities[i]=entity.strip().lower()

# %%
primarary_entities
# Out:
# ['steinberg library',
#  'counseling center',
#  'wilf campus libraries',
#  'mendel gottesman',
#  'resnick campus library',
#  'website',
#  'samuel gottesman library',
#  'office of disability services',
#  'counseling center',
#  'counseling center',
#  'registration',
#  'students',
#  'students',
#  'crn',
#  'time',
#  'students',
#  'katz school',
#  'students',
#  'social media platforms',
#  'abraham oxilas',
#  'abraham oxilas',
#  'abraham oxilas',
#  'abraham oxilas',
#  'abraham oxilas',
#  'abraham oxilas',
#  'abraham oxilas',
#  'abraham oxilas',
#  'abraham oxilas',
#  'abraham oxilas',
#  'alexandra laghezza',
#  'alexandra laghezza',
#  'alexandra laghezza',
#  'alexandra laghezza',
#  'alexandra laghezza',
#  'alexandra laghezza',
#  'alexandra laghezza',
#  'alexandra laghezza',
#  'alexandra laghezza',
#  'alexandra laghezza',
#  'alexandra wagner',
#  'wagner',
#  'wagner',
#  'wagner',
#  'wagner',
#  'wagner',
#  'wagner',
#  'wagner',
#  'wagner',
# ...

# %% [markdown]
# Make count of each entity in the list of entities

# %% [markdown]
# As the next stage we are going to to assign all professors to category faculty

# %%
import pandas as pd

# %%
df=pd.DataFrame(columns=['entity','category'])

# %%
df
# Out:
# Empty DataFrame
# Columns: [entity, category]
# Index: []

# %%
# GitHub folder URL
github_folder_url = 'https://github.com/atreish/yukatzbot/tree/main/Text%20data'

# Fetch the list of text files from the GitHub folder
response = requests.get(github_folder_url)
response.raise_for_status()
folder_contents = response.text

# Extract the filenames
file_names = re.findall(r'[A-Za-z\s0-9%20]+.txt', folder_contents)

# %%
faculty_names=list(map(lambda x: re.sub(r'.txt','',x),file_names))

# %%
faculty_names=list(map(lambda x: re.sub(r'%20',' ',x),faculty_names))

# %%
faculty_names=list(map(lambda x: re.sub(r'\d','',x),faculty_names))

# %%
faculty_names
# Out:
# ['Abraham Oxilas',
#  'Abraham Oxilas',
#  'Aleksandr Zhuk',
#  'Aleksandr Zhuk',
#  'Alexandra Wagner',
#  'Alexandra Wagner',
#  'Alexandra Wagner',
#  'Alexandra Wagner',
#  'Amarildo Gjondrekaj',
#  'Amarildo Gjondrekaj',
#  'Amit Rakhit',
#  'Amit Rakhit',
#  'Levi',
#  'Levi',
#  'Levi',
#  'Levi',
#  'Andrew Christler',
#  'Andrew Christler',
#  'Andrew Christler',
#  'Andrew Christler',
#  'Andy Catlin',
#  'Andy Catlin',
#  'Antonella Marini',
#  'Antonella Marini',
#  'Antonella Marini',
#  'Antonella Marini',
#  'Asaf Hochman',
#  'Asaf Hochman',
#  'Atif Ghauri',
#  'Atif Ghauri',
#  'Avi Gilon',
#  'Avi Gilon',
#  'Avi Giloni',
#  'Avi Giloni',
#  'Brandon Chiazza',
#  'Brandon Chiazza',
#  'Brian Malkin',
#  'Brian Malkin',
#  'Brian Malkin',
#  'Brian Malkin',
#  'Brittany Palmer',
#  'Brittany Palmer',
#  'Burdin Hickok',
#  'Burdin Hickok',
#  'Christina Brennan',
#  'Christina Brennan',
#  'Daniel Davidson',
#  'Daniel Davidson',
#  'David Imre',
#  'David Imre',
# ...

# %%
no_faculty_names=['ai',
 'biotech',
 'cyber',
 'data-analytics',
 'digital-marketing-media',
 'math-ma',
 'math-phd',
 'occupational-therapy',
 'physician-assistant',
 'physics',
 'slp', 'Patents_Licensing_and_IP_Policy','New Student Welcome Packet - Spring 2023'
]

# %%
faculty_names=list(set(faculty_names))

# %%
faculty_names
# Out:
# ['',
#  'Alexandra Wagner',
#  'Javier Guillen',
#  'Avi Gilon',
#  'Stav Kemeny',
#  'Aleksandr Zhuk',
#  'David Imre',
#  'Michaela Medved',
#  'David Whipple',
#  'assistant',
#  'Atif Ghauri',
#  'Rana Khan',
#  'Lawrence Fulton',
#  'commands',
#  'Levi',
#  'Policy',
#  'Amarildo Gjondrekaj',
#  'Jeff Nieman',
#  'Elaine Zacharakis Loumbas',
#  'Pablo Roldan',
#  'Yuri Katz',
#  'analytics',
#  'Robert Frdiman',
#  'Asaf Hochman',
#  'William Wedo',
#  'Gary Sztajnman',
#  'Robert Friedman',
#  'Thom Kennon',
#  'media',
#  'Andrew Christler',
#  'Sivie Naimer',
#  'Robin Brizzi',
#  'Samuel Strum',
#  'ai',
#  'Tia Hopkins',
#  'Fredy Zypman',
#  'Joanne Tombrakos',
#  'Tom Balga',
#  'Abraham Oxilas',
#  'Daniel Davidson',
#  'Avi Giloni',
#  'Jeff Wunderman',
#  'Esteban Wesson',
#  'Brian Malkin',
#  'phd',
#  'Peter Nandori',
#  'Lea Ferreira dos Santos',
#  'Mindy Garfinkel',
#  'Gabriel Cwilich',
#  ' Spring ',
#  'Neer Asherie',
#  'Jochen Raimann',
#  'Marian Gidea',
# ...

# %%
import string

# %%
for i, name in enumerate(faculty_names):
 faculty_names[i]=name.lower()

# %%
unassigned_entities=[]
appended_data=[]
primarary_entities_set=list(set(primarary_entities))
# Iterate over the entity_count_priority keys
for entity in primarary_entities_set:
    # Check if the entity is in faculty_names
    if entity in faculty_names:
        # Create a dictionary with the data for the row
        row_data = {'entity': entity, 'category': 'faculty'}
        # Append the row data to the list
        appended_data.append(row_data)
        # Remove the entity from unassigned_entities
    else: unassigned_entities.append(entity)

# Convert the list of dictionaries to a DataFrame
df = pd.DataFrame(appended_data)

# Concatenate the original DataFrame 'df' with the

# %%
len(unassigned_entities)
# Out:
# 215

# %%
len(df)
# Out:
# 82

# %%
unassigned_entities
# Out:
# ['university of central florida',
#  'philly.com',
#  'experience',
#  'medical training',
#  'waldman-levi',
#  'professor sergey buldyrev',
#  'passport',
#  'honors program',
#  'katz school',
#  'hudson technology group',
#  'nysspa',
#  'potential applications',
#  'clinical trials transformation initiative',
#  'demand',
#  'prodan',
#  'mazars',
#  'university',
#  'job growth rate',
#  'clinical externships',
#  'auditory-verbal therapy',
#  'wunderman',
#  'm.a. in mathematics program',
#  'division of natural',
#  'marini',
#  'dwayne a. williams',
#  'occupational therapy',
#  'technology',
#  'music composition application',
#  'marketing analytics support',
#  'san francisco open exchange',
#  'median salary',
#  'program',
#  'mendel gottesman',
#  'rakhit',
#  'cryptocurrency trading company',
#  'professor neer asherie',
#  'job growth',
#  'pas',
#  'neuromuscular electrical stimulation',
#  'antifreeze proteins',
#  'proteins',
# ...

# %%
unassigned_entities=list(map(lambda x: x.split("\n\n"),unassigned_entities))

# %%
len(unassigned_entities)
# Out:
# 215

# %%
unassigned_entities
# Out:
# [['university of central florida'],
#  ['philly.com'],
#  ['experience'],
#  ['medical training'],
#  ['waldman-levi'],
#  ['professor sergey buldyrev'],
#  ['passport'],
#  ['honors program'],
#  ['katz school'],
#  ['hudson technology group'],
#  ['nysspa'],
#  ['potential applications'],
#  ['clinical trials transformation initiative'],
#  ['demand'],
#  ['prodan'],
#  ['mazars'],
#  ['university'],
#  ['job growth rate'],
#  ['clinical externships'],
#  ['auditory-verbal therapy'],
#  ['wunderman'],
#  ['m.a. in mathematics program'],
#  ['division of natural'],
#  ['marini'],
#  ['dwayne a. williams'],
#  ['occupational therapy'],
#  ['technology'],
#  ['music composition application'],
#  ['marketing analytics support'],
#  ['san francisco open exchange'],
#  ['median salary'],
#  ['program'],
#  ['mendel gottesman'],
#  ['rakhit'],
#  ['cryptocurrency trading company'],
#  ['professor neer asherie'],
#  ['job growth'],
#  ['pas'],
#  ['neuromuscular electrical stimulation'],
# ...

# %%
df
# Out:
#                   entity category
# 0      joseph panzarella  faculty
# 1            amit rakhit  faculty
# 2            atif ghauri  faculty
# 3       antonella marini  faculty
# 4       andrew christler  faculty
# ..                   ...      ...
# 79  sai praveen kadiyala  faculty
# 80         burdin hickok  faculty
# 81       sergey fogelson  faculty
# 82         peter nandori  faculty
# 83           david sweet  faculty
#
# [84 rows x 2 columns]

# %% [markdown]
# Sometimes CHATgpt returned only lastname of professor we also should

# %%
import pandas as pd
import os
import openai
import requests
import re
from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv()) # read local .env file


def get_completion_from_messages(messages,
                                 model="gpt-3.5-turbo",
                                 temperature=0,
                                 max_tokens=500):
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=temperature,
        max_tokens=max_tokens,
    )
    return response.choices[0].message["content"]

# %%
delimiter='####'
first_part=list(unassigned_entities.keys())[:]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-681-2533347e6156> in <cell line: 2>()
#       1 delimiter='####'
# ----> 2 first_part=list(unassigned_entities.keys())[:]
#
# AttributeError: 'list' object has no attribute 'keys'

# %%
len(first_part)

# %%
    user_message_1 = f"""
   COULD YOU PLEASE DIVIDE BY GROUP THESE NETITIES AND MAKE NAMES FOR THE GROUPS: """
    messages = [
{'role':'system',
 'content': str(first_part)},
{'role':'user',
 'content': f"{delimiter}{user_message_1}{delimiter}"},
]

# %%
 category_and_product_respons1 = get_completion_from_messages(messages)

# %% [markdown]
# n1. Academic and Research: research areas, geometric analysis, free radicals, professor Buldyrev, tech fellows, antifreeze proteins, Mendel Gottesman, professor Asherie, clinical trials, Jupyter notebooks, biotech fellows, Zaslavsky Prize, electronic research, Katz School, average salary, medical training, Professor Sergey, transfer learning, professional organization, admissions criteria, current projects, Ovid Therapeutics, Steinberg Library, Joseph Weber, curriculum development, Institute for, honors program, manifold learning, research interests, person mentioned, medical centers, centers of, math fellows, Yeshiva University, occupational therapists, common core, mass communications, Harrison and, the voice, Stern College, ownership policy, office of, faculty members, documentary movie, Michael Brin, clinical externships, Jay and, Wilf Campus, capstone project, Brin Fellowship, Society for, counseling center, University of, division of, national science, research grants, career paths, social media, potential applications.\n\n2. Job and Career: job opportunities, median salary, salary range, job growth, international students, brand USA, job opportunities, marketing analytics, hedge fund, herjavec group, Davidson Advisory, Mazars USA.\n\n3. Medical and Healthcare: laryngeal massage, clinical trials, TransCelerate BioPharma, PANCE prep, occupational therapy, neuromuscular electrical, physician assistant, protein self, protein phases, easy water, medical centers, centers of, occupational therapists.\n\n4. Technology and Innovation: tech fellows, Jupyter notebooks, biotech fellows, electronic research, transfer learning, Japanese robotic.\n\n5. Education and Training: admissions criteria, medical training, math fellows, Yeshiva University, common core, Stern College, clinical externships, capstone project, Brin Fellowship.\n\n6. Science and Research Funding: research areas, free radicals, Mendel Gottesman, Zaslavsky Prize, Institute for, research grants, national science.\n\n7. Business and Consulting: Yorkville Consulting, business relationship, industry expectation, herjavec group, Davidson Advisory, Mazars USA.\n\n8. Arts and Media: mass communications, documentary movie, music composition.\n\n9. Libraries and Resources: Steinberg Library.\n\n10. Miscellaneous: Passport Project, Enterprise Data, Troy Dargin, Dwayne A, Flipmed Medical, Visions in, cryptocurrency'

# %%
df
# Out:
#                   entity       category
# 0      joseph panzarella        faculty
# 1            amit rakhit        faculty
# 2            atif ghauri        faculty
# 3       antonella marini        faculty
# 4       andrew christler        faculty
# ..                   ...            ...
# 160    counseling center  miscellaneous
# 161  mass communications  miscellaneous
# 162        median salary  miscellaneous
# 163     passport project  miscellaneous
# 164        protein phase  miscellaneous
#
# [165 rows x 2 columns]

# %%
category_and_product_respons1='Group 1: Faculty\n- Counseling skills\n- Davidson Advisory\n- Kemeny\n- Jessica Rifkind\n- Mendel Gottesman\n- Prodan\n- Marchand\n- Professor Neer Asherie\n- Professor Buldyrev\n- Professor Asherie\n- Professor Buldyrev\n- Professor Asherie\n\nGroup 2: Academic Programs and Research\n- San Francisco Open Exchange\n- M.S. in Data Analytics and Visualization Program\n- Common Core State Standards\n- M.S.\n- NYSSPA\n- M.S. in Speech-Language Pathology Program\n- M.S. in Speech-Language Pathology\n- M.S. in Data Analytics and Visualization\n- M.A. in Mathematics Program\n- Electronic Research Archive\n- Katz School\n- M.S. in Digital Marketing and Media Program\n\nGroup 3: University and Campus Life\n- Yeshiva University\n- Passport\n- YU\n- Centers of Excellence\n- Office of Disability Services\n- Resnick Campus Library\n- Samuel Gottesman Library\n- Wilf Campus Libraries\n- Harrison and Star\n- Steinberg Library\n- Stern College for Women\n- Jay and Jeanie Schottenstein Honors Program\n\nGroup 4: Career and Professional Development\n- Association of Clinical Research Professionals\n- IQVIA\n- Citigroup\n- Society for Clinical Research Sites\n- Brand USA\n- Business Relationship Management Institute\n- Fibrocontrol\n- Wunderman\n- Hudson Technology Group\n- Ovid Therapeutics\n- Transcelerate Biopharma\n- Yorkville Consulting\n- Mazars\n- Mazars USA\n- Herjavec Group\n\nGroup 5: Miscellaneous\n- Students\n- Demand\n- Skills\n- Computer Vision\n- Average Salary\n- Protein Phases\n- Free Radicals\n- Fellows Program\n- Tech Fellows Program\n- Charlotte Business Intelligence User Group\n- Passport\n- Publication\n- Jupyter Notebooks\n- National Science Foundation Award\n- Registration\n- Company\n- TSSLD\n- Music Composition Application\n- Tools\n- H-Index\n- Zaslavsky Prize\n- Ph.D. Program\n- Society for Clinical Research Sites\n- University of Miami\n- Laryngeal Massage\n- Mitsubishi UFJ Financial Group\n- Protein Self-Assembly\n- Capstone Project\n- Proteins\n- Challenges\n- Curriculum Development\n- Documentary Movie\n- Time\n- Hedge Fund\n- Job Growth\n- Biotech Fellows Program\n- Fibrocontrol\n- Internships\n- Medical Training\n- Astrophysics\n- PANCE Prep Pearls\n- Brin Fellowship\n- Faculty Members\n- Michael Brin Research Fellowship\n- Ran Ri\n- Resnick Campus Library\n- Purpose\n- Honors Program\n- Salaries\n- Jedlik Anyos Fellowship\n- Lee Silverman Voice Treatment\n- Website\n- Roldan\n- Samuel Gottesman Library\n- Hudson Technology Group\n- B.A.\n- Shape Analysis\n- Antifreeze Proteins\n- Wagner\n- Mlawski\n- Harrison and Star\n- Cost\n- Garfinkel\n- Margaret L. and Anderson Graduate Teaching Award\n- Ovid Therapeutics\n- Wilf Campus Libraries\n- Manifold Learning\n- Japanese Robotic Lunar Spacecraft\n- Barrera\n- Auditory-Verbal Therapy\n- Grant\n- Brabble\n- Bodie\n- Admissions Criteria\n- PAs\n- Journal\n- Courses\n- Job Opportunities\n- Research Areas\n- Professor Asherie\n- Responsible\n- Meister\n- Occupational Therapy Doctorate Program\n- PANCE\n- Industries\n- Book Title\n- Potential Applications\n- Alexandra Laghezza\n- Professor Buldyrev\n- Benefit\n- Clinical Externships\n- Program\n- Philly.com\n- Master\n- Transcelerate Biopharma\n- Building\n- M.S. in Speech-Language Pathology\n- Flipmed Medical App\n- Ownership Policy\n- Transfer Learning\n- Current Projects\n- Person Mentioned in the Text\n- Esentire\n- Steinberg Library\n- Mazars\n- Lea F. Santos\n- Physician Assistant\n- FDA-Regulated Products\n- Yorkville Consulting\n- SNI\n- RI\n- Salary Range\n- Dwayne A. Williams\n- Rapp\n- Waldman-Levi\n- Strategies\n- Classes\n- M.S. in Data Analytics and Visualization\n- Occupational Therapists\n- Income\n- Technology\n- Protein Phase Behavior\n- Industry Expectation\n- Career Paths\n- Cryptocurrency Trading Company\n- Initiative\n- Math Fellows Program\n- Occupational Therapy\n- M.A. in Mathematics Program\n- Electronic Research Archive\n- Visions in Voice\n- Author\n- Neuromuscular Electrical Stimulation\n- The Voice'

# %%
def extract_entities(df,category_and_product_response):
  appended_data=[]

  for groups in category_and_product_response.split("\n\n"):
   if groups!='':
    groups=re.sub(r'Group\s+\d+:','',groups)

    groups=groups.split('\n-')

    groups=[x for x in groups if x!='']

    if groups[0]=='Faculty and Staff':
      groups[0]='faculty'


    type_group=groups[0].strip().lower()
    for i in range(1,len(groups)):
        # Create a dictionary with the data for the row
        row_data = {'entity': groups[i].lower(), 'category': type_group}
        # Append the row data to the list
        appended_data.append(row_data)
        df = df.append(pd.DataFrame(row_data, index=[0]), ignore_index=True)

        # Remove the entity from unassigned_entities
  return df

# %%
df=extract_entities(df,category_and_product_respons1)

# %%
df
# Out:
#                                     entity       category
# 0                        joseph panzarella        faculty
# 1                              amit rakhit        faculty
# 2                              atif ghauri        faculty
# 3                         antonella marini        faculty
# 4                         andrew christler        faculty
# ..                                     ...            ...
# 264            electronic research archive  miscellaneous
# 265                       visions in voice  miscellaneous
# 266                                 author  miscellaneous
# 267   neuromuscular electrical stimulation  miscellaneous
# 268                              the voice  miscellaneous
#
# [269 rows x 2 columns]

# %%
df['category'].unique()
# Out:
# array(['faculty', 'academic programs and research',
#        'university and campus life',
#        'career and professional development', 'miscellaneous'],
#       dtype=object)
