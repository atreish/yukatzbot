# %%
# Importing librariesd and loading openAI API key

import pandas as pd
import os
import openai
from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv()) # read local .env file

openai.api_key  = os.environ['OPENAI_API_KEY']

# %%
# Function to get the response from ChatGPT through API key

def get_completion_from_messages(messages, 
                                 model="gpt-3.5-turbo", 
                                 temperature=0, 
                                 max_tokens=1000):
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=temperature, 
        max_tokens=max_tokens, 
    )
    return response.choices[0].message["content"]

# %%
def ent_extract(i):
    """
    This function takes enties and returns their types
    """
    messages =  [  
    {'role':'system', 
     'content':"""You are an helpful assistant who\
     defines entity types"""},    
    {'role':'user', 
     'content':f"Extract cateogries from. this entites :{i} , you should  sign to one of these categories: {categories}. give. answers without discussion. give me in template.I need categories for all entities",}  
    ] 
    response = get_completion_from_messages(messages)
    return response

# %%
df=pd.read_csv('df.csv')

# %%
categories=['faculty', 'academic programs and research',
       'university and campus life',
       'career and professional development', 'faculty and experts',
       'miscellaneous']

# %%
entities1 = [ent_extract(i) for i in df[:50]['entities']]

# %%
entities1
# Out:
# ['Primary entity: Steinberg Library\nCategory: university and campus life\n\nSecondary entity: phone number\nCategory: miscellaneous',
#  'Primary entities: Counseling Center\nCategory: University and campus life\n\nSecondary entities: services\nCategory: Miscellaneous',
#  'Primary entity: Wilf Campus libraries\nCategory: academic programs and research\n\nSecondary entity: address\nCategory: university and campus life',
#  'Primary entity: Mendel Gottesman & Pollack Libraries\nCategory: university and campus life\n\nSecondary entity: phone number\nCategory: miscellaneous',
#  'Primary entity: Resnick Campus library\nCategory: university and campus life\n\nSecondary entity: address\nCategory: miscellaneous',
#  'Primary entity: website\nCategory: miscellaneous\n\nSecondary entity: online library access\nCategory: academic programs and research',
# ...

# %%
entities2 = [ent_extract(i) for i in df[50:100]['entities']]

# %%
entities2
# Out:
# ['Primary entity: Amarildo Gjondrekaj\nCategory: faculty\n\nSecondary entity: Mastercard\nCategory: miscellaneous',
#  'Primary entity: Amarildo Gjondrekaj\nCategory: faculty\n\nSecondary entity: Mastercard\nCategory: miscellaneous',
#  "Primary entity: Amarildo Gjondrekaj\nCategory: faculty\n\nSecondary entity: Katz's Data Visualization and Analytics program\nCategory: academic programs and research",
#  'Primary entity: Amarildo Gjondrekaj\nCategory: faculty\n\nSecondary entity: corporate strategy\nCategory: miscellaneous',
#  'Primary entity: Amarildo Gjondrekaj\nCategory: faculty\n\nSecondary entity: birthplace\nCategory: miscellaneous',
#  'Primary entity: Amarildo Gjondrekaj\nCategory: faculty\n\nSecondary entity: the States\nCategory: miscellaneous',
#  'Primary entities: Amarildo Gjondrekaj\nCategory: faculty\n\nSecondary entities: organizations, board member\nCategory: miscellaneous',
# ...

# %%
entities3 = [ent_extract(i) for i in df[100:150]['entities']]

# %%
entities4 = [ent_extract(i) for i in df[150:200]['entities']]

# %%
entities5 = [ent_extract(i) for i in df[200:250]['entities']]

# %%
entities6 = [ent_extract(i) for i in df[250:300]['entities']]

# %%
entities7 = [ent_extract(i) for i in df[300:350]['entities']]

# %%
entities8 = [ent_extract(i) for i in df[350:400]['entities']]

# %%
entities9 = [ent_extract(i) for i in df[400:450]['entities']]

# %%
entities10 = [ent_extract(i) for i in df[450:500]['entities']]

# %%
entities11 = [ent_extract(i) for i in df[500:550]['entities']]

# %%
entities12 = [ent_extract(i) for i in df[550:600]['entities']]

# %%
entities13 = [ent_extract(i) for i in df[600:650]['entities']]

# %%
entities14 = [ent_extract(i) for i in df[650:700]['entities']]

# %%
entities_par1=entities1+entities2+entities3+entities4+entities5+entities6+entities7+entities8+entities9+entities10+entities11+entities12+entities13+entities14

# %%
entities_par1
# Out:
# ['Primary entity: Steinberg Library\nCategory: university and campus life\n\nSecondary entity: phone number\nCategory: miscellaneous',
#  'Primary entities: Counseling Center\nCategory: University and campus life\n\nSecondary entities: services\nCategory: Miscellaneous',
#  'Primary entity: Wilf Campus libraries\nCategory: academic programs and research\n\nSecondary entity: address\nCategory: university and campus life',
#  'Primary entity: Mendel Gottesman & Pollack Libraries\nCategory: university and campus life\n\nSecondary entity: phone number\nCategory: miscellaneous',
#  'Primary entity: Resnick Campus library\nCategory: university and campus life\n\nSecondary entity: address\nCategory: miscellaneous',
#  'Primary entity: website\nCategory: miscellaneous\n\nSecondary entity: online library access\nCategory: academic programs and research',
# ...
